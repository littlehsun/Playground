# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.xkcd()

# %%
x1=linspace(0.1,5)
x2=linspace(-3,3)
x31=linspace(0,3)
x32=linspace(-3,0)
y41=linspace(0,pi)
y42=linspace(-pi,0)

# %%
plot(x1,(1/x1),'r')
plot(10,10)
plot(0,0)

# %%
plot(x2,(9-x2**2)**0.5,'r')
plot(x2,-(9-x2**2)**0.5,'r')
plot(5,0)

# %%
plot(x31,2*x31,'r')
plot(x32,-2*x32,'r')
plot(6,0)

# %%
plot(-3*(sin(y41)),y41,'r')
plot(-3*-(sin(y42)),y42,'r')
plot(3,3)
plot(0,-3)
